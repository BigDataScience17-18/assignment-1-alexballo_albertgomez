# %% [markdown]
# # Assigment 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## Get Data

# %%
data_original = pd.read_csv('Pressupostos_dels_ens_municipals_de_Catalunya.csv')

# %% [markdown]
# ## Preparing Data

# %%
data_16 = data_original.loc[data_original.ANY_EXERCICI == '01/01/2016 12:00:00 AM']
data_16.shape
# Out:
# (624092, 11)

# %%
data_16_aj = data_16.loc[data_16.NOM_COMPLERT.str.contains('Ajuntament')]
data_16_aj.shape
# Out:
# (434340, 11)

# %%
data_16_aj_no0=data_16_aj.loc[data_16_aj.IMPORT > 0.0]

# %%
name, counts = np.unique(data_16_aj_no0.NOM_COMPLERT, return_counts = True)
print(np.amax(counts), np.amin(counts), np.mean(counts), np.median(counts))
# Out:
# 387 47 201.99092970521542 193.0

# %%
np.unique(data_16_aj_no0.TIPUS_PARTIDA)
# Out:
# array(['D', 'I'], dtype=object)

# %%
np.unique(data_16_aj_no0.TIPUS_CLASSIF)
# Out:
# array(['E', 'F'], dtype=object)

# %%
np.unique(data_16_aj_no0.NIVELL)
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# ## Data Cleaning

# %%
data_sorted=data_16_aj_no0[['NOM_COMPLERT','CODI_ENS','TIPUS_PARTIDA','TIPUS_CLASSIF','CODI_PANTALLA', 'NIVELL', 'IMPORT','DESCRIPCIO','ESTRUCTURA']].astype(str)

data_sorted.sort_values(['CODI_ENS','TIPUS_PARTIDA','TIPUS_CLASSIF','CODI_PANTALLA'])
# Out:
#                               NOM_COMPLERT    CODI_ENS TIPUS_PARTIDA  \
# 4011                 Ajuntament d'Agullana  1700100000             D
# 4012                 Ajuntament d'Agullana  1700100000             D
# 4013                 Ajuntament d'Agullana  1700100000             D
# 4014                 Ajuntament d'Agullana  1700100000             D
# 4015                 Ajuntament d'Agullana  1700100000             D
# 4016                 Ajuntament d'Agullana  1700100000             D
# 4017                 Ajuntament d'Agullana  1700100000             D
# 4018                 Ajuntament d'Agullana  1700100000             D
# 4019                 Ajuntament d'Agullana  1700100000             D
# 4020                 Ajuntament d'Agullana  1700100000             D
# 4021                 Ajuntament d'Agullana  1700100000             D
# 4022                 Ajuntament d'Agullana  1700100000             D
# 4023                 Ajuntament d'Agullana  1700100000             D
# 4024                 Ajuntament d'Agullana  1700100000             D
# 4025                 Ajuntament d'Agullana  1700100000             D
# 4026                 Ajuntament d'Agullana  1700100000             D
# 4027                 Ajuntament d'Agullana  1700100000             D
# 4028                 Ajuntament d'Agullana  1700100000             D
# 4029                 Ajuntament d'Agullana  1700100000             D
# 4030                 Ajuntament d'Agullana  1700100000             D
# 4031                 Ajuntament d'Agullana  1700100000             D
# 4032                 Ajuntament d'Agullana  1700100000             D
# 4033                 Ajuntament d'Agullana  1700100000             D
# 4034                 Ajuntament d'Agullana  1700100000             D
# 4035                 Ajuntament d'Agullana  1700100000             D
# 4036                 Ajuntament d'Agullana  1700100000             D
# 4037                 Ajuntament d'Agullana  1700100000             D
# 4038                 Ajuntament d'Agullana  1700100000             D
# 4039                 Ajuntament d'Agullana  1700100000             D
# 4040                 Ajuntament d'Agullana  1700100000             D
# ...                                    ...         ...           ...
# 379036  Ajuntament de la Palma de Cervelló   890580001             I
# 379037  Ajuntament de la Palma de Cervelló   890580001             I
# 379038  Ajuntament de la Palma de Cervelló   890580001             I
# 379039  Ajuntament de la Palma de Cervelló   890580001             I
# 379040  Ajuntament de la Palma de Cervelló   890580001             I
# 379041  Ajuntament de la Palma de Cervelló   890580001             I
# 379042  Ajuntament de la Palma de Cervelló   890580001             I
# 379043  Ajuntament de la Palma de Cervelló   890580001             I
# 379044  Ajuntament de la Palma de Cervelló   890580001             I
# 379045  Ajuntament de la Palma de Cervelló   890580001             I
# 379046  Ajuntament de la Palma de Cervelló   890580001             I
# 379047  Ajuntament de la Palma de Cervelló   890580001             I
# 379048  Ajuntament de la Palma de Cervelló   890580001             I
# 379049  Ajuntament de la Palma de Cervelló   890580001             I
# 379050  Ajuntament de la Palma de Cervelló   890580001             I
# 379051  Ajuntament de la Palma de Cervelló   890580001             I
# 379052  Ajuntament de la Palma de Cervelló   890580001             I
# 379053  Ajuntament de la Palma de Cervelló   890580001             I
# 379054  Ajuntament de la Palma de Cervelló   890580001             I
# 379055  Ajuntament de la Palma de Cervelló   890580001             I
# 379056  Ajuntament de la Palma de Cervelló   890580001             I
# 379057  Ajuntament de la Palma de Cervelló   890580001             I
# 379058  Ajuntament de la Palma de Cervelló   890580001             I
# 379059  Ajuntament de la Palma de Cervelló   890580001             I
# 379060  Ajuntament de la Palma de Cervelló   890580001             I
# 379061  Ajuntament de la Palma de Cervelló   890580001             I
# 379062  Ajuntament de la Palma de Cervelló   890580001             I
# 379063  Ajuntament de la Palma de Cervelló   890580001             I
# 379064  Ajuntament de la Palma de Cervelló   890580001             I
# 379065  Ajuntament de la Palma de Cervelló   890580001             I
#
#        TIPUS_CLASSIF CODI_PANTALLA NIVELL      IMPORT  \
# 4011               E           1.0      1   287505.72
# 4012               E          10.0      2    17505.72
# 4013               E         100.0      3    17505.72
# 4014               E         100.0      4    17505.72
# 4015               E          12.0      2     38000.0
# 4016               E         120.0      3     12000.0
# 4017               E         120.0      4     12000.0
# 4018               E         121.0      3     26000.0
# 4019               E         121.0      4     26000.0
# 4020               E          13.0      2    165000.0
# 4021               E         130.0      3    159000.0
# 4022               E         130.0      4    159000.0
# 4023               E         131.0      3      6000.0
# 4024               E          16.0      2     67000.0
# 4025               E         160.0      3     67000.0
# 4026               E         160.0      4     67000.0
# 4027               E           2.0      1    505433.7
# 4028               E          21.0      2    122500.0
# 4029               E         210.0      3     75000.0
# 4030               E         212.0      3     42000.0
# 4031               E         214.0      3      1500.0
# 4032               E         216.0      3      4000.0
# 4033               E          22.0      2    381333.7
# 4034               E         220.0      3     11000.0
# 4035               E         220.0      4     11000.0
# 4036               E         221.0      3     90000.0
# 4037               E         221.0      4     60000.0
# 4038               E        221.03      4      5000.0
# 4039               E        221.99      4     25000.0
# 4040               E         222.0      3     10000.0
# ...              ...           ...    ...         ...
# 379036             E          33.0      2     53000.0
# 379037             E         331.0      3     53000.0
# 379038             E          38.0      2      1700.0
# 379039             E         389.0      3      1700.0
# 379040             E          39.0      2     83500.0
# 379041             E         391.0      3     48000.0
# 379042             E         391.2      4     48000.0
# 379043             E         393.0      3     10500.0
# 379044             E         399.0      3     25000.0
# 379045             E           4.0      1  1125401.74
# 379046             E          42.0      2    561601.0
# 379047             E         420.0      3    561601.0
# 379048             E         420.0      4    561601.0
# 379049             E          45.0      2    107188.0
# 379050             E         450.0      3    107188.0
# 379051             E         450.0      4     82688.0
# 379052             E         450.8      4     24500.0
# 379053             E          46.0      2   456612.74
# 379054             E         461.0      3   218006.26
# 379055             E         464.0      3   162603.12
# 379056             E         465.0      3    76003.36
# 379057             E           5.0      1     39509.0
# 379058             E          52.0      2        50.0
# 379059             E          55.0      2     15409.0
# 379060             E         550.0      3     15409.0
# 379061             E          59.0      2     24050.0
# 379062             E         599.0      3     24050.0
# 379063             E           7.0      1     39000.0
# 379064             E          76.0      2     39000.0
# 379065             E         761.0      3     39000.0
#
#                                                DESCRIPCIO ESTRUCTURA
# 4011                                 Despeses de personal          1
# 4012                 Òrgans de govern i personal directiu         10
# 4013    Retr. bàs. i altres rem. membres òrgans de govern       1000
# 4014                                Retribucions bàsiques     100000
# 4015                                  Personal funcionari         12
# 4016                                Retribucions bàsiques       1200
# 4017                                     Sous del grup A1     120000
# 4018                         Retribucions complementàries       1201
# 4019                             Complement de destinació     120100
# 4020                                     Personal laboral         13
# 4021                                          Laboral fix       1300
# 4022                                Retribucions bàsiques     130000
# 4023                                     Laboral temporal       1301
# 4024    Quotes, prestac. i desp. socials a/c de l'ocup...         16
# 4025                                       Quotes socials       1600
# 4026                                     Seguretat Social     160000
# 4027                  Despeses corrents en béns i serveis          2
# 4028               Reparacions, manteniment i conservació         21
# 4029                     Infraestructures i béns naturals       2100
# 4030                      Edificis i altres construccions       2102
# 4031                                Elements de transport       2104
# 4032                  Equips per a processos d'informació       2106
# 4033                Material, subministraments i d'altres         22
# 4034                                   Material d'oficina       2200
# 4035                            Ordinari no inventariable     220000
# 4036                                     Subministraments       2201
# 4037                                    Energia elèctrica     220100
# 4038                            Combustibles i carburants     220103
# 4039                              Altres subministraments     220199
# 4040                                        Comunicacions       2202
# ...                                                   ...        ...
# 379036  T. ús privatiu o aprofit. espai domini públ. l...         33
# 379037                       Taxa per entrada de vehicles       3301
# 379038               Reintegraments d'operacions corrents         38
# 379039        Altres reintegraments d'operacions corrents       3809
# 379040                                   Altres ingressos         39
# 379041                                             Multes       3901
# 379042   Multes per infraccions d'ordenança de circulació     390120
# 379043                               Interessos de demora       3903
# 379044                          Altres ingressos diversos       3909
# 379045                            Transferències corrents          4
# 379046                      De l'Administració de l'Estat         42
# 379047              De l'Administració general de l'Estat       4200
# 379048             Participació en els tributs de l'Estat     420000
# 379049                            De comunitats autònomes         45
# 379050               De l'administració general de les CA       4500
# 379051       Fons de cooperació local de Catalunya (FCLC)     450000
# 379052  Altres subvencions cor. de l'Adm. general de l...     450080
# 379053                                  D'entitats locals         46
# 379054                De diputacions, consells o cabildos       4601
# 379055                             D'àrees metropolitanes       4604
# 379056                                       De comarques       4605
# 379057                             Ingressos patrimonials          5
# 379058                             Interessos de dipòsits         52
# 379059  Productes de concessions i aprofitaments espec...         55
# 379060  De concessions adm. amb contraprestació periòdica       5500
# 379061                      Altres ingressos patrimonials         59
# 379062                      Altres ingressos patrimonials       5909
# 379063                          Transferències de capital          7
# 379064                                  D'entitats locals         76
# 379065                De diputacions, consells o cabildos       7601
#
# [178156 rows x 9 columns]

# %% [markdown]
# # Data Investigation
#
# ## Número ajuntaments

# %%
nom=np.unique(data_16_aj_no0.NOM_COMPLERT)
print('Número ajuntaments',len(nom))
# Out:
# Número ajuntaments 882

# %% [markdown]
# ###### Will you need to transform data in a some way in order to be able to compare different budgets?
# SÍ
# ##### How?
# * Veure ingressos i despeses de cada ajuntament
# * Veure la gestió de pressupost de cada ajuntament
# * Veure ajuntaments amb beneficis i deutes
# - Veure número de descripcions per cada ajuntament

# %% [markdown]
# ## Ingressos i despeses de cada ajuntament

# %%
def get_import_ajuntament(data, codi_ens, tipus):
    r= np.unique(data.loc[(data.CODI_ENS == codi_ens) & (data.TIPUS_PARTIDA == tipus) & (data.NIVELL == '1') , ['IMPORT']].IMPORT)
    suma=0
    for price in r:
            suma=suma+(float(price))
          
    return suma

def get_ingressos_despesa_per_ajuntament(data):
    codi_ens = np.unique(data.CODI_ENS)
    nom = np.unique(data.NOM_COMPLERT)



    data_comparative = pd.DataFrame(columns=['NOM_COMPLERT','CODI_ENS', 'DESPESES','INGRESSOS'])
    
    i = 0
    for ens in codi_ens:
        despesses = get_import_ajuntament(data, ens, 'D')
        ingressos = get_import_ajuntament(data, ens, 'I')
        data_comparative.loc[i] = [nom[i], ens, despesses,ingressos]
        print(data_comparative.loc[i])
        i = i +1
        
    return data_comparative


ingres_despesa_total = get_ingressos_despesa_per_ajuntament(data_sorted)
ingres_despesa_total.sort_values(['DESPESES'])
# Out:
# NOM_COMPLERT    Ajuntament d'Abrera
# CODI_ENS                 1700100000
# DESPESES                 2.1276e+06
# INGRESSOS                1.0638e+06
# Name: 0, dtype: object
# NOM_COMPLERT    Ajuntament d'Agramunt
# CODI_ENS                   1700250006
# DESPESES                  1.97735e+06
# INGRESSOS                  1.3316e+06
# Name: 1, dtype: object
# NOM_COMPLERT    Ajuntament d'Aguilar de Segarra
# CODI_ENS                             1700310007
# DESPESES                                 567860
# INGRESSOS                                285080
# Name: 2, dtype: object
# NOM_COMPLERT    Ajuntament d'Agullana
# CODI_ENS                   1700460009
# DESPESES                    1.326e+06
# INGRESSOS                      663000
# Name: 3, dtype: object
# NOM_COMPLERT    Ajuntament d'Aiguafreda
# CODI_ENS                     1700590004
# DESPESES                    1.29892e+06
# INGRESSOS                        655710
# Name: 4, dtype: object
# NOM_COMPLERT    Ajuntament d'Aiguamúrcia
# CODI_ENS                      1700620002
# DESPESES                     6.54787e+06
# INGRESSOS                    3.27393e+06
# Name: 5, dtype: object
# NOM_COMPLERT    Ajuntament d'Aiguaviva
# CODI_ENS                    1700780001
# DESPESES                   3.82554e+06
# INGRESSOS                  1.91277e+06
# Name: 6, dtype: object
# NOM_COMPLERT    Ajuntament d'Aitona
# CODI_ENS                 1700840003
# DESPESES                9.33966e+06
# INGRESSOS               4.66983e+06
# Name: 7, dtype: object
# NOM_COMPLERT    Ajuntament d'Albanyà
# CODI_ENS                  1700970005
# DESPESES                 1.42831e+07
# INGRESSOS                7.14156e+06
# Name: 8, dtype: object
# NOM_COMPLERT    Ajuntament d'Albatàrrec
# CODI_ENS                     1701010007
# DESPESES                    1.04892e+06
# INGRESSOS                        524459
# Name: 9, dtype: object
# NOM_COMPLERT    Ajuntament d'Albesa
# CODI_ENS                 1701180001
# DESPESES                 1.6873e+06
# INGRESSOS                    843652
# Name: 10, dtype: object
# NOM_COMPLERT    Ajuntament d'Albinyana
# CODI_ENS                    1701230008
# DESPESES                   1.60529e+06
# INGRESSOS                       802647
# Name: 11, dtype: object
# NOM_COMPLERT    Ajuntament d'Albons
# CODI_ENS                 1701390004
# DESPESES                 2.1522e+07
# INGRESSOS                1.0461e+07
# Name: 12, dtype: object
# NOM_COMPLERT    Ajuntament d'Alcanar
# CODI_ENS                  1701440003
# DESPESES                      455720
# INGRESSOS                     227860
# Name: 13, dtype: object
# NOM_COMPLERT    Ajuntament d'Alcanó
# CODI_ENS                 1701570005
# DESPESES                 3.9967e+07
# INGRESSOS               1.99835e+07
# Name: 14, dtype: object
# NOM_COMPLERT    Ajuntament d'Alcarràs
# CODI_ENS                   1701600000
# DESPESES                  1.90087e+06
# INGRESSOS                      950437
# Name: 15, dtype: object
# NOM_COMPLERT    Ajuntament d'Alcoletge
# CODI_ENS                    1701820002
# DESPESES                    1.5415e+06
# INGRESSOS                       770950
# Name: 16, dtype: object
# NOM_COMPLERT    Ajuntament d'Alcover
# CODI_ENS                  1701950006
# DESPESES                 5.87369e+06
# INGRESSOS                2.93685e+06
# Name: 17, dtype: object
# NOM_COMPLERT    Ajuntament d'Aldover
# CODI_ENS                  1702090004
# DESPESES                  7.7368e+06
# INGRESSOS                 3.8684e+06
# Name: 18, dtype: object
# NOM_COMPLERT    Ajuntament d'Alella
# CODI_ENS                 1702160009
# DESPESES                1.23678e+06
# INGRESSOS                    618391
# Name: 19, dtype: object
# NOM_COMPLERT    Ajuntament d'Alfara de Carles
# CODI_ENS                           1702210007
# DESPESES                          2.68976e+07
# INGRESSOS                         1.34488e+07
# Name: 20, dtype: object
# NOM_COMPLERT    Ajuntament d'Alfarràs
# CODI_ENS                   1702370005
# DESPESES                  9.15188e+07
# INGRESSOS                 4.57594e+07
# Name: 21, dtype: object
# NOM_COMPLERT    Ajuntament d'Alforja
# CODI_ENS                  1702420002
# DESPESES                  2.9358e+06
# INGRESSOS                 1.5706e+06
# Name: 22, dtype: object
# NOM_COMPLERT    Ajuntament d'Alfés
# CODI_ENS                1702550006
# DESPESES               2.23765e+06
# INGRESSOS              1.11882e+06
# Name: 23, dtype: object
# NOM_COMPLERT    Ajuntament d'Algerri
# CODI_ENS                  1702680001
# DESPESES                  1.2464e+06
# INGRESSOS                     623199
# Name: 24, dtype: object
# NOM_COMPLERT    Ajuntament d'Alguaire
# CODI_ENS                   1702740003
# DESPESES                   6.9644e+06
# INGRESSOS                  3.4822e+06
# Name: 25, dtype: object
# NOM_COMPLERT    Ajuntament d'Alió
# CODI_ENS               1702800000
# DESPESES                   664400
# INGRESSOS                  332200
# Name: 26, dtype: object
# NOM_COMPLERT    Ajuntament d'Almacelles
# CODI_ENS                     1702930008
# DESPESES                         828736
# INGRESSOS                        425530
# Name: 27, dtype: object
# NOM_COMPLERT    Ajuntament d'Almatret
# CODI_ENS                   1703070005
# DESPESES                  1.26485e+06
# INGRESSOS                      632425
# Name: 28, dtype: object
# NOM_COMPLERT    Ajuntament d'Almenar
# CODI_ENS                  1703140003
# DESPESES                      630068
# INGRESSOS                     315034
# Name: 29, dtype: object
# NOM_COMPLERT    Ajuntament d'Almoster
# CODI_ENS                   1703290004
# DESPESES                  1.29435e+07
# INGRESSOS                 6.47175e+06
# Name: 30, dtype: object
# NOM_COMPLERT    Ajuntament d'Alp
# CODI_ENS              1703350006
# DESPESES             1.75485e+07
# INGRESSOS            8.77424e+06
# Name: 31, dtype: object
# NOM_COMPLERT    Ajuntament d'Alpens
# CODI_ENS                 1703400000
# DESPESES                 3.8866e+07
# INGRESSOS                1.9433e+07
# Name: 32, dtype: object
# NOM_COMPLERT    Ajuntament d'Alpicat
# CODI_ENS                  1703530008
# DESPESES                 1.06833e+06
# INGRESSOS                     534167
# Name: 33, dtype: object
# NOM_COMPLERT    Ajuntament d'Alòs de Balaguer
# CODI_ENS                           1703660009
# DESPESES                          6.41133e+06
# INGRESSOS                         3.20567e+06
# Name: 34, dtype: object
# NOM_COMPLERT    Ajuntament d'Amer
# CODI_ENS               1703720002
# DESPESES                   570000
# INGRESSOS                  285000
# Name: 35, dtype: object
# NOM_COMPLERT    Ajuntament d'Amposta
# CODI_ENS                  1703880001
# DESPESES                 2.04987e+06
# INGRESSOS                1.02494e+06
# Name: 36, dtype: object
# NOM_COMPLERT    Ajuntament d'Anglesola
# CODI_ENS                    1703910007
# DESPESES                   8.07369e+06
# INGRESSOS                  4.03685e+06
# Name: 37, dtype: object
# NOM_COMPLERT    Ajuntament d'Anglès
# CODI_ENS                 1704050006
# DESPESES                     868410
# INGRESSOS                    434205
# Name: 38, dtype: object
# NOM_COMPLERT    Ajuntament d'Arbeca
# CODI_ENS                 1704120002
# DESPESES                1.00306e+06
# INGRESSOS                    501528
# Name: 39, dtype: object
# NOM_COMPLERT    Ajuntament d'Arbolí
# CODI_ENS                 1704270005
# DESPESES                1.58671e+06
# INGRESSOS                    793355
# Name: 40, dtype: object
# NOM_COMPLERT    Ajuntament d'Arbúcies
# CODI_ENS                   1704330008
# DESPESES                  1.06635e+06
# INGRESSOS                      533174
# Name: 41, dtype: object
# NOM_COMPLERT    Ajuntament d'Arenys de Mar
# CODI_ENS                        1704480001
# DESPESES                       1.90231e+07
# INGRESSOS                      9.51153e+06
# Name: 42, dtype: object
# NOM_COMPLERT    Ajuntament d'Arenys de Munt
# CODI_ENS                         1704640003
# DESPESES                        2.05236e+06
# INGRESSOS                       1.03388e+06
# Name: 43, dtype: object
# NOM_COMPLERT    Ajuntament d'Argelaguer
# CODI_ENS                     1704700000
# DESPESES                     4.2837e+07
# INGRESSOS                   2.14185e+07
# Name: 44, dtype: object
# NOM_COMPLERT    Ajuntament d'Argentona
# CODI_ENS                    1704860009
# DESPESES                   1.77411e+08
# INGRESSOS                  8.87057e+07
# Name: 45, dtype: object
# NOM_COMPLERT    Ajuntament d'Arnes
# CODI_ENS                1704990004
# DESPESES               9.97205e+06
# INGRESSOS              4.98602e+06
# Name: 46, dtype: object
# NOM_COMPLERT    Ajuntament d'Arres
# CODI_ENS                1705020002
# DESPESES                1.8129e+06
# INGRESSOS                   906448
# Name: 47, dtype: object
# NOM_COMPLERT    Ajuntament d'Artesa de Lleida
# CODI_ENS                           1705190004
# DESPESES                               565486
# INGRESSOS                              282743
# Name: 48, dtype: object
# NOM_COMPLERT    Ajuntament d'Artesa de Segre
# CODI_ENS                          1705240003
# DESPESES                              464200
# INGRESSOS                             232100
# Name: 49, dtype: object
# NOM_COMPLERT    Ajuntament d'Artés
# CODI_ENS                1705450006
# DESPESES               1.76161e+06
# INGRESSOS                   880807
# Name: 50, dtype: object
# NOM_COMPLERT    Ajuntament d'Ascó
# CODI_ENS               1705580001
# DESPESES                   997400
# INGRESSOS                  498700
# Name: 51, dtype: object
# NOM_COMPLERT    Ajuntament d'Aspa
# CODI_ENS               1705610007
# DESPESES              4.18725e+06
# INGRESSOS             2.09362e+06
# Name: 52, dtype: object
# NOM_COMPLERT    Ajuntament d'Avinyonet de Puigventós
# CODI_ENS                                  1705770005
# DESPESES                                    2.27e+06
# INGRESSOS                                  1.135e+06
# Name: 53, dtype: object
# NOM_COMPLERT    Ajuntament d'Avinyonet del Penedès
# CODI_ENS                                1705830008
# DESPESES                                    565779
# INGRESSOS                                   282890
# Name: 54, dtype: object
# NOM_COMPLERT    Ajuntament d'Avinyó
# CODI_ENS                 1706000000
# DESPESES                1.20477e+06
# INGRESSOS                    602387
# Name: 55, dtype: object
# NOM_COMPLERT    Ajuntament d'Avià
# CODI_ENS               1706170005
# DESPESES                 1.68e+06
# INGRESSOS                  840000
# Name: 56, dtype: object
# NOM_COMPLERT    Ajuntament d'Es Bòrdes
# CODI_ENS                    1706220002
# DESPESES                   4.06496e+07
# INGRESSOS                  2.03248e+07
# Name: 57, dtype: object
# NOM_COMPLERT    Ajuntament d'Esparreguera
# CODI_ENS                       1706380001
# DESPESES                         1.31e+06
# INGRESSOS                          655000
# Name: 58, dtype: object
# NOM_COMPLERT    Ajuntament d'Espinelves
# CODI_ENS                     1706430008
# DESPESES                    1.09112e+06
# INGRESSOS                        545562
# Name: 59, dtype: object
# NOM_COMPLERT    Ajuntament d'Esplugues de Llobregat
# CODI_ENS                                 1706560009
# DESPESES                                     999158
# INGRESSOS                                    499579
# Name: 60, dtype: object
# NOM_COMPLERT    Ajuntament d'Espolla
# CODI_ENS                  1706690004
# DESPESES                 1.12644e+08
# INGRESSOS                5.63218e+07
# Name: 61, dtype: object
# NOM_COMPLERT    Ajuntament d'Esponellà
# CODI_ENS                    1706750006
# DESPESES                   1.65095e+06
# INGRESSOS                       825476
# Name: 62, dtype: object
# NOM_COMPLERT    Ajuntament d'Espot
# CODI_ENS                1706940003
# DESPESES                  1.68e+06
# INGRESSOS                   815000
# Name: 63, dtype: object
# NOM_COMPLERT    Ajuntament d'Estamariu
# CODI_ENS                    1707080001
# DESPESES                        604583
# INGRESSOS                       302292
# Name: 64, dtype: object
# NOM_COMPLERT    Ajuntament d'Estaràs
# CODI_ENS                  1707150006
# DESPESES                   2.152e+06
# INGRESSOS                  1.076e+06
# Name: 65, dtype: object
# NOM_COMPLERT    Ajuntament d'Esterri d'Àneu
# CODI_ENS                         1707360009
# DESPESES                        4.91106e+06
# INGRESSOS                       2.45553e+06
# Name: 66, dtype: object
# NOM_COMPLERT    Ajuntament d'Esterri de Cardós
# CODI_ENS                            1707410007
# DESPESES                           1.22018e+06
# INGRESSOS                               610090
# Name: 67, dtype: object
# NOM_COMPLERT    Ajuntament d'Horta de Sant Joan
# CODI_ENS                             1707540003
# DESPESES                                 671572
# INGRESSOS                                377886
# Name: 68, dtype: object
# NOM_COMPLERT    Ajuntament d'Hostalric
# CODI_ENS                    1707670005
# DESPESES                        415334
# INGRESSOS                       207667
# Name: 69, dtype: object
# NOM_COMPLERT    Ajuntament d'Igualada
# CODI_ENS                   1707730008
# DESPESES                  1.80797e+06
# INGRESSOS                      910987
# Name: 70, dtype: object
# NOM_COMPLERT    Ajuntament d'Isona i Conca Dellà
# CODI_ENS                              1707890004
# DESPESES                             3.19167e+06
# INGRESSOS                            1.60553e+06
# Name: 71, dtype: object
# NOM_COMPLERT    Ajuntament d'Isòvol
# CODI_ENS                 1707920002
# DESPESES                2.14685e+08
# INGRESSOS               1.07343e+08
# Name: 72, dtype: object
# NOM_COMPLERT    Ajuntament d'Ivars d'Urgell
# CODI_ENS                         1708060009
# DESPESES                             547000
# INGRESSOS                            273500
# Name: 73, dtype: object
# NOM_COMPLERT    Ajuntament d'Ivars de Noguera
# CODI_ENS                           1708130008
# DESPESES                          1.31359e+06
# INGRESSOS                              656797
# Name: 74, dtype: object
# NOM_COMPLERT    Ajuntament d'Ivorra
# CODI_ENS                 1708280001
# DESPESES                 2.2444e+06
# INGRESSOS                1.1307e+06
# Name: 75, dtype: object
# NOM_COMPLERT    Ajuntament d'Odèn
# CODI_ENS               1708340003
# DESPESES              7.63528e+06
# INGRESSOS             3.81764e+06
# Name: 76, dtype: object
# NOM_COMPLERT    Ajuntament d'Ogassa
# CODI_ENS                 1708490004
# DESPESES                1.36115e+06
# INGRESSOS                    705576
# Name: 77, dtype: object
# NOM_COMPLERT    Ajuntament d'Olesa de Bonesvalls
# CODI_ENS                              1708520002
# DESPESES                                  646200
# INGRESSOS                                 323100
# Name: 78, dtype: object
# NOM_COMPLERT    Ajuntament d'Olesa de Montserrat
# CODI_ENS                              1708650006
# DESPESES                             1.27078e+07
# INGRESSOS                            6.47105e+06
# Name: 79, dtype: object
# NOM_COMPLERT    Ajuntament d'Oliana
# CODI_ENS                 1708710007
# DESPESES                     667738
# INGRESSOS                    333869
# Name: 80, dtype: object
# NOM_COMPLERT    Ajuntament d'Oliola
# CODI_ENS                 1708870005
# DESPESES                1.94327e+06
# INGRESSOS                    972633
# Name: 81, dtype: object
# NOM_COMPLERT    Ajuntament d'Olius
# CODI_ENS                1708900000
# DESPESES               1.52401e+07
# INGRESSOS              7.58505e+06
# Name: 82, dtype: object
# NOM_COMPLERT    Ajuntament d'Olivella
# CODI_ENS                   1709040003
# DESPESES                   1.3216e+06
# INGRESSOS                      660800
# Name: 83, dtype: object
# NOM_COMPLERT    Ajuntament d'Olost
# CODI_ENS                1709110007
# DESPESES               1.01755e+06
# INGRESSOS                   508775
# Name: 84, dtype: object
# NOM_COMPLERT    Ajuntament d'Olot
# CODI_ENS               1709260009
# DESPESES              1.83486e+07
# INGRESSOS              9.1743e+06
# Name: 85, dtype: object
# NOM_COMPLERT    Ajuntament d'Olvan
# CODI_ENS                1709320002
# DESPESES               2.11239e+06
# INGRESSOS              1.05619e+06
# Name: 86, dtype: object
# NOM_COMPLERT    Ajuntament d'Olèrdola
# CODI_ENS                   1709500000
# DESPESES                  1.27397e+08
# INGRESSOS                 6.36985e+07
# Name: 87, dtype: object
# NOM_COMPLERT    Ajuntament d'Ordis
# CODI_ENS                1709630008
# DESPESES                    397064
# INGRESSOS                   211032
# Name: 88, dtype: object
# NOM_COMPLERT    Ajuntament d'Organyà
# CODI_ENS                  1709850006
# DESPESES                       1e+06
# INGRESSOS                     531957
# Name: 89, dtype: object
# NOM_COMPLERT    Ajuntament d'Orís
# CODI_ENS               1710300000
# DESPESES              1.48763e+07
# INGRESSOS             7.43814e+06
# Name: 90, dtype: object
# NOM_COMPLERT    Ajuntament d'Os de Balaguer
# CODI_ENS                         1710580001
# DESPESES                             654260
# INGRESSOS                            327130
# Name: 91, dtype: object
# NOM_COMPLERT    Ajuntament d'Osor
# CODI_ENS               1710610007
# DESPESES                   412820
# INGRESSOS                  206410
# Name: 92, dtype: object
# NOM_COMPLERT    Ajuntament d'Ossó de Sió
# CODI_ENS                      1710770005
# DESPESES                     1.03452e+06
# INGRESSOS                         517260
# Name: 93, dtype: object
# NOM_COMPLERT    Ajuntament d'Ullastret
# CODI_ENS                    1710960009
# DESPESES                   2.27877e+06
# INGRESSOS                  1.13939e+06
# Name: 94, dtype: object
# NOM_COMPLERT    Ajuntament d'Ulldecona
# CODI_ENS                    1711000000
# DESPESES                   3.11073e+06
# INGRESSOS                  1.55537e+06
# Name: 95, dtype: object
# NOM_COMPLERT    Ajuntament d'Ulldemolins
# CODI_ENS                      1711170005
# DESPESES                     2.20503e+06
# INGRESSOS                    1.10252e+06
# Name: 96, dtype: object
# NOM_COMPLERT    Ajuntament d'Ullà
# CODI_ENS               1711220002
# DESPESES                   730000
# INGRESSOS                  365000
# Name: 97, dtype: object
# NOM_COMPLERT    Ajuntament d'Ultramort
# CODI_ENS                    1711430008
# DESPESES                   5.75088e+07
# INGRESSOS                  2.87544e+07
# Name: 98, dtype: object
# NOM_COMPLERT    Ajuntament d'Urús
# CODI_ENS               1711560009
# DESPESES                   566109
# INGRESSOS                  283055
# Name: 99, dtype: object
# NOM_COMPLERT    Ajuntament d'Àger
# CODI_ENS               1711690004
# DESPESES                   632382
# INGRESSOS                  316191
# Name: 100, dtype: object
# NOM_COMPLERT    Ajuntament d'Òdena
# CODI_ENS                1711750006
# DESPESES               6.67629e+07
# INGRESSOS              3.33815e+07
# Name: 101, dtype: object
# NOM_COMPLERT    Ajuntament d'Òrrius
# CODI_ENS                 1711810007
# DESPESES                4.51439e+07
# INGRESSOS                2.2572e+07
# Name: 102, dtype: object
# NOM_COMPLERT    Ajuntament de Badalona
# CODI_ENS                    1711940003
# DESPESES                        627711
# INGRESSOS                       314006
# Name: 103, dtype: object
# NOM_COMPLERT    Ajuntament de Badia del Vallès
# CODI_ENS                            1712080001
# DESPESES                           3.68998e+06
# INGRESSOS                          1.84499e+06
# Name: 104, dtype: object
# NOM_COMPLERT    Ajuntament de Bagà
# CODI_ENS                1712150006
# DESPESES                    831350
# INGRESSOS                   415675
# Name: 105, dtype: object
# NOM_COMPLERT    Ajuntament de Balaguer
# CODI_ENS                    1712360009
# DESPESES                   1.40762e+06
# INGRESSOS                       703812
# Name: 106, dtype: object
# NOM_COMPLERT    Ajuntament de Balsareny
# CODI_ENS                     1712410007
# DESPESES                    1.05288e+07
# INGRESSOS                   5.26439e+06
# Name: 107, dtype: object
# NOM_COMPLERT    Ajuntament de Banyeres del Penedès
# CODI_ENS                                1712540003
# DESPESES                                    440212
# INGRESSOS                                   220106
# Name: 108, dtype: object
# NOM_COMPLERT    Ajuntament de Banyoles
# CODI_ENS                    1712670005
# DESPESES                   1.04008e+06
# INGRESSOS                       520038
# Name: 109, dtype: object
# NOM_COMPLERT    Ajuntament de Barbens
# CODI_ENS                   1712890004
# DESPESES                   1.2246e+06
# INGRESSOS                      612300
# Name: 110, dtype: object
# NOM_COMPLERT    Ajuntament de Barberà de la Conca
# CODI_ENS                               1712920002
# DESPESES                                   726750
# INGRESSOS                                  363375
# Name: 111, dtype: object
# NOM_COMPLERT    Ajuntament de Barberà del Vallès
# CODI_ENS                              1713060009
# DESPESES                                  963042
# INGRESSOS                                 481521
# Name: 112, dtype: object
# NOM_COMPLERT    Ajuntament de Barcelona
# CODI_ENS                     1713280001
# DESPESES                    6.15684e+06
# INGRESSOS                   3.07842e+06
# Name: 113, dtype: object
# NOM_COMPLERT    Ajuntament de Bassella
# CODI_ENS                    1713340003
# DESPESES                   3.09761e+06
# INGRESSOS                   1.5488e+06
# Name: 114, dtype: object
# NOM_COMPLERT    Ajuntament de Batea
# CODI_ENS                 1713490004
# DESPESES                1.15078e+06
# INGRESSOS                    575388
# Name: 115, dtype: object
# NOM_COMPLERT    Ajuntament de Bausen
# CODI_ENS                  1713520002
# DESPESES                 1.01019e+06
# INGRESSOS                     505095
# Name: 116, dtype: object
# NOM_COMPLERT    Ajuntament de Begues
# CODI_ENS                  1713650006
# DESPESES                      821016
# INGRESSOS                     412758
# Name: 117, dtype: object
# NOM_COMPLERT    Ajuntament de Begur
# CODI_ENS                 1713710007
# DESPESES                    8.3e+06
# INGRESSOS                  4.15e+06
# Name: 118, dtype: object
# NOM_COMPLERT    Ajuntament de Belianes
# CODI_ENS                    1713870005
# DESPESES                    3.7055e+06
# INGRESSOS                  1.85275e+06
# Name: 119, dtype: object
# NOM_COMPLERT    Ajuntament de Bell-lloc d'Urgell
# CODI_ENS                              1713900000
# DESPESES                             3.34521e+06
# INGRESSOS                             1.6726e+06
# Name: 120, dtype: object
# NOM_COMPLERT    Ajuntament de Bellaguarda
# CODI_ENS                       1714040003
# DESPESES                      7.82973e+06
# INGRESSOS                     3.91487e+06
# Name: 121, dtype: object
# NOM_COMPLERT    Ajuntament de Bellcaire d'Empordà
# CODI_ENS                               1714260009
# DESPESES                              6.56528e+06
# INGRESSOS                             3.28264e+06
# Name: 122, dtype: object
# NOM_COMPLERT    Ajuntament de Bellmunt d'Urgell
# CODI_ENS                             1714320002
# DESPESES                                 458660
# INGRESSOS                                229330
# Name: 123, dtype: object
# NOM_COMPLERT    Ajuntament de Bellmunt del Priorat
# CODI_ENS                                1714470005
# DESPESES                                    956945
# INGRESSOS                                   478472
# Name: 124, dtype: object
# NOM_COMPLERT    Ajuntament de Bellpuig
# CODI_ENS                    1714500000
# DESPESES                    4.3307e+06
# INGRESSOS                  2.16535e+06
# Name: 125, dtype: object
# NOM_COMPLERT    Ajuntament de Bellvei
# CODI_ENS                   1714630008
# DESPESES                  6.50518e+06
# INGRESSOS                 3.25259e+06
# Name: 126, dtype: object
# NOM_COMPLERT    Ajuntament de Bellver de Cerdanya
# CODI_ENS                               1714790004
# DESPESES                              1.99404e+07
# INGRESSOS                             9.97018e+06
# Name: 127, dtype: object
# NOM_COMPLERT    Ajuntament de Bellvís
# CODI_ENS                   1714850006
# DESPESES                     3.85e+06
# INGRESSOS                   1.925e+06
# Name: 128, dtype: object
# NOM_COMPLERT    Ajuntament de Benavent de Segrià
# CODI_ENS                              1714980001
# DESPESES                                  638181
# INGRESSOS                                 319090
# Name: 129, dtype: object
# NOM_COMPLERT    Ajuntament de Benifallet
# CODI_ENS                      1715010007
# DESPESES                     7.12089e+06
# INGRESSOS                    3.56045e+06
# Name: 130, dtype: object
# NOM_COMPLERT    Ajuntament de Benissanet
# CODI_ENS                      1715180001
# DESPESES                          461928
# INGRESSOS                         230964
# Name: 131, dtype: object
# NOM_COMPLERT    Ajuntament de Berga
# CODI_ENS                 1715230008
# DESPESES                  6.847e+07
# INGRESSOS                3.4235e+07
# Name: 132, dtype: object
# NOM_COMPLERT    Ajuntament de Besalú
# CODI_ENS                  1715390004
# DESPESES                      704038
# INGRESSOS                     352019
# Name: 133, dtype: object
# NOM_COMPLERT    Ajuntament de Bescanó
# CODI_ENS                   1715440003
# DESPESES                       260980
# INGRESSOS                      130490
# Name: 134, dtype: object
# NOM_COMPLERT    Ajuntament de Beuda
# CODI_ENS                 1715570005
# DESPESES                 4.8755e+07
# INGRESSOS               2.43775e+07
# Name: 135, dtype: object
# NOM_COMPLERT    Ajuntament de Bigues i Riells
# CODI_ENS                           1715760009
# DESPESES                               246940
# INGRESSOS                              123470
# Name: 136, dtype: object
# NOM_COMPLERT    Ajuntament de Biosca
# CODI_ENS                  1715820002
# DESPESES                      910000
# INGRESSOS                     455000
# Name: 137, dtype: object
# NOM_COMPLERT    Ajuntament de Biure
# CODI_ENS                 1715950006
# DESPESES                 2.9734e+06
# INGRESSOS                1.4867e+06
# Name: 138, dtype: object
# NOM_COMPLERT    Ajuntament de Blancafort
# CODI_ENS                      1716090004
# DESPESES                     5.35498e+07
# INGRESSOS                    2.67749e+07
# Name: 139, dtype: object
# NOM_COMPLERT    Ajuntament de Blanes
# CODI_ENS                  1716160009
# DESPESES                   2.482e+06
# INGRESSOS                  1.241e+06
# Name: 140, dtype: object
# NOM_COMPLERT    Ajuntament de Boadella i les Escaules
# CODI_ENS                                   1716210007
# DESPESES                                       505670
# INGRESSOS                                      252835
# Name: 141, dtype: object
# NOM_COMPLERT    Ajuntament de Bolvir
# CODI_ENS                  1716370005
# DESPESES                  7.4137e+06
# INGRESSOS                3.70685e+06
# Name: 142, dtype: object
# NOM_COMPLERT    Ajuntament de Bonastre
# CODI_ENS                    1716420002
# DESPESES                    1.1114e+07
# INGRESSOS                    5.607e+06
# Name: 143, dtype: object
# NOM_COMPLERT    Ajuntament de Bordils
# CODI_ENS                   1716550006
# DESPESES                  2.84539e+06
# INGRESSOS                  1.4227e+06
# Name: 144, dtype: object
# NOM_COMPLERT    Ajuntament de Borrassà
# CODI_ENS                    1716680001
# DESPESES                   1.43323e+06
# INGRESSOS                       716617
# Name: 145, dtype: object
# NOM_COMPLERT    Ajuntament de Bossòst
# CODI_ENS                   1716740003
# DESPESES                  7.82848e+06
# INGRESSOS                 3.91424e+06
# Name: 146, dtype: object
# NOM_COMPLERT    Ajuntament de Bot
# CODI_ENS               1716800000
# DESPESES                   504640
# INGRESSOS                  299598
# Name: 147, dtype: object
# NOM_COMPLERT    Ajuntament de Botarell
# CODI_ENS                    1716930008
# DESPESES                      5.86e+06
# INGRESSOS                     2.93e+06
# Name: 148, dtype: object
# NOM_COMPLERT    Ajuntament de Bovera
# CODI_ENS                  1717070005
# DESPESES                      688890
# INGRESSOS                     344445
# Name: 149, dtype: object
# NOM_COMPLERT    Ajuntament de Breda
# CODI_ENS                 1717140003
# DESPESES                     609800
# INGRESSOS                    314200
# Name: 150, dtype: object
# NOM_COMPLERT    Ajuntament de Brunyola
# CODI_ENS                    1717290004
# DESPESES                        980000
# INGRESSOS                       490000
# Name: 151, dtype: object
# NOM_COMPLERT    Ajuntament de Bàscara
# CODI_ENS                   1717350006
# DESPESES                       531027
# INGRESSOS                      265514
# Name: 152, dtype: object
# NOM_COMPLERT    Ajuntament de Cabacés
# CODI_ENS                   1717400000
# DESPESES                       571414
# INGRESSOS                      285707
# Name: 153, dtype: object
# NOM_COMPLERT    Ajuntament de Cabanabona
# CODI_ENS                      1717530008
# DESPESES                     1.55853e+06
# INGRESSOS                         792703
# Name: 154, dtype: object
# NOM_COMPLERT    Ajuntament de Cabanelles
# CODI_ENS                      1717660009
# DESPESES                          446400
# INGRESSOS                         223200
# Name: 155, dtype: object
# NOM_COMPLERT    Ajuntament de Cabanes
# CODI_ENS                   1717720002
# DESPESES                  1.91339e+06
# INGRESSOS                      956947
# Name: 156, dtype: object
# NOM_COMPLERT    Ajuntament de Cabra del Camp
# CODI_ENS                          1718050006
# DESPESES                         2.36283e+07
# INGRESSOS                        1.18141e+07
# Name: 157, dtype: object
# NOM_COMPLERT    Ajuntament de Cabrera de Mar
# CODI_ENS                          1718120002
# DESPESES                          1.4172e+07
# INGRESSOS                          7.086e+06
# Name: 158, dtype: object
# NOM_COMPLERT    Ajuntament de Cabrils
# CODI_ENS                   1718270005
# DESPESES                   1.0232e+06
# INGRESSOS                      512100
# Name: 159, dtype: object
# NOM_COMPLERT    Ajuntament de Cabó
# CODI_ENS                1718330008
# DESPESES                    829172
# INGRESSOS                   414586
# Name: 160, dtype: object
# NOM_COMPLERT    Ajuntament de Cadaqués
# CODI_ENS                    1718480001
# DESPESES                   2.35284e+06
# INGRESSOS                  1.17642e+06
# Name: 161, dtype: object
# NOM_COMPLERT    Ajuntament de Calaf
# CODI_ENS                 1718510007
# DESPESES                7.21047e+06
# INGRESSOS               3.60523e+06
# Name: 162, dtype: object
# NOM_COMPLERT    Ajuntament de Calafell
# CODI_ENS                    1718640003
# DESPESES                   6.91275e+06
# INGRESSOS                  3.45638e+06
# Name: 163, dtype: object
# NOM_COMPLERT    Ajuntament de Calders
# CODI_ENS                   1718700000
# DESPESES                  1.82331e+06
# INGRESSOS                      911656
# Name: 164, dtype: object
# NOM_COMPLERT    Ajuntament de Caldes d'Estrac
# CODI_ENS                           1718860009
# DESPESES                               649981
# INGRESSOS                              324991
# Name: 165, dtype: object
# NOM_COMPLERT    Ajuntament de Caldes de Malavella
# CODI_ENS                               1718990004
# DESPESES                              3.41123e+06
# INGRESSOS                             1.70562e+06
# Name: 166, dtype: object
# NOM_COMPLERT    Ajuntament de Caldes de Montbui
# CODI_ENS                             1719030008
# DESPESES                              1.778e+06
# INGRESSOS                                889000
# Name: 167, dtype: object
# NOM_COMPLERT    Ajuntament de Calella
# CODI_ENS                   1719100000
# DESPESES                       655060
# INGRESSOS                      327530
# Name: 168, dtype: object
# NOM_COMPLERT    Ajuntament de Calldetenes
# CODI_ENS                       1719250006
# DESPESES                           832300
# INGRESSOS                          416150
# Name: 169, dtype: object
# NOM_COMPLERT    Ajuntament de Callús
# CODI_ENS                  1719310007
# DESPESES                   9.202e+06
# INGRESSOS                  4.601e+06
# Name: 170, dtype: object
# NOM_COMPLERT    Ajuntament de Calonge
# CODI_ENS                   1719460009
# DESPESES                   1.0875e+06
# INGRESSOS                      543748
# Name: 171, dtype: object
# NOM_COMPLERT    Ajuntament de Calonge de Segarra
# CODI_ENS                              1719590004
# DESPESES                             1.45135e+06
# INGRESSOS                                 725674
# Name: 172, dtype: object
# NOM_COMPLERT    Ajuntament de Camarasa
# CODI_ENS                    1719620002
# DESPESES                        603050
# INGRESSOS                       301525
# Name: 173, dtype: object
# NOM_COMPLERT    Ajuntament de Camarles
# CODI_ENS                    1719780001
# DESPESES                        696376
# INGRESSOS                       348188
# Name: 174, dtype: object
# NOM_COMPLERT    Ajuntament de Cambrils
# CODI_ENS                    1719840003
# DESPESES                   1.27199e+06
# INGRESSOS                       635997
# Name: 175, dtype: object
# NOM_COMPLERT    Ajuntament de Campdevànol
# CODI_ENS                       1719970005
# DESPESES                      3.51577e+07
# INGRESSOS                     1.75789e+07
# Name: 176, dtype: object
# NOM_COMPLERT    Ajuntament de Campelles
# CODI_ENS                     1720010007
# DESPESES                     1.0988e+06
# INGRESSOS                        549402
# Name: 177, dtype: object
# NOM_COMPLERT    Ajuntament de Campllong
# CODI_ENS                     1720180001
# DESPESES                         648146
# INGRESSOS                        324073
# Name: 178, dtype: object
# NOM_COMPLERT    Ajuntament de Camprodon
# CODI_ENS                     1720230008
# DESPESES                    2.17406e+07
# INGRESSOS                   1.08703e+07
# Name: 179, dtype: object
# NOM_COMPLERT    Ajuntament de Camós
# CODI_ENS                 1720390004
# DESPESES                     479200
# INGRESSOS                    243000
# Name: 180, dtype: object
# NOM_COMPLERT    Ajuntament de Canejan
# CODI_ENS                   1720440003
# DESPESES                    1.959e+06
# INGRESSOS                      979500
# Name: 181, dtype: object
# NOM_COMPLERT    Ajuntament de Canet d'Adri
# CODI_ENS                        1720570005
# DESPESES                        1.3234e+06
# INGRESSOS                           661700
# Name: 182, dtype: object
# NOM_COMPLERT    Ajuntament de Canet de Mar
# CODI_ENS                        1720600000
# DESPESES                         1.336e+06
# INGRESSOS                           668000
# Name: 183, dtype: object
# NOM_COMPLERT    Ajuntament de Canovelles
# CODI_ENS                      1720760009
# DESPESES                     6.86479e+06
# INGRESSOS                     3.4324e+06
# Name: 184, dtype: object
# NOM_COMPLERT    Ajuntament de Cantallops
# CODI_ENS                      1720820002
# DESPESES                     2.47424e+06
# INGRESSOS                    1.23712e+06
# Name: 185, dtype: object
# NOM_COMPLERT    Ajuntament de Capafonts
# CODI_ENS                     1720950006
# DESPESES                    2.51994e+06
# INGRESSOS                   1.25997e+06
# Name: 186, dtype: object
# NOM_COMPLERT    Ajuntament de Capellades
# CODI_ENS                      1721090004
# DESPESES                     1.85158e+06
# INGRESSOS                         925789
# Name: 187, dtype: object
# NOM_COMPLERT    Ajuntament de Capmany
# CODI_ENS                   1721160009
# DESPESES                   2.0312e+06
# INGRESSOS                  1.0156e+06
# Name: 188, dtype: object
# NOM_COMPLERT    Ajuntament de Capolat
# CODI_ENS                   1721210007
# DESPESES                       612218
# INGRESSOS                      306109
# Name: 189, dtype: object
# NOM_COMPLERT    Ajuntament de Capçanes
# CODI_ENS                    1721370005
# DESPESES                   2.01848e+07
# INGRESSOS                  1.00924e+07
# Name: 190, dtype: object
# NOM_COMPLERT    Ajuntament de Cardedeu
# CODI_ENS                    1721420002
# DESPESES                   1.39528e+06
# INGRESSOS                       697641
# Name: 191, dtype: object
# NOM_COMPLERT    Ajuntament de Cardona
# CODI_ENS                   1721550006
# DESPESES                   6.5177e+06
# INGRESSOS                 3.25885e+06
# Name: 192, dtype: object
# NOM_COMPLERT    Ajuntament de Caseres
# CODI_ENS                   1721740003
# DESPESES                       826092
# INGRESSOS                      413046
# Name: 193, dtype: object
# NOM_COMPLERT    Ajuntament de Casserres
# CODI_ENS                     1721800000
# DESPESES                    1.37199e+06
# INGRESSOS                        685996
# Name: 194, dtype: object
# NOM_COMPLERT    Ajuntament de Cassà de la Selva
# CODI_ENS                             1722070005
# DESPESES                             3.5071e+06
# INGRESSOS                           1.75355e+06
# Name: 195, dtype: object
# NOM_COMPLERT    Ajuntament de Castell de Mur
# CODI_ENS                          1722140003
# DESPESES                         9.11532e+06
# INGRESSOS                        4.55766e+06
# Name: 196, dtype: object
# NOM_COMPLERT    Ajuntament de Castell de l'Areny
# CODI_ENS                              1722290004
# DESPESES                                  336000
# INGRESSOS                                 168000
# Name: 197, dtype: object
# NOM_COMPLERT    Ajuntament de Castell-Platja d'Aro
# CODI_ENS                                1722350006
# DESPESES                                2.0566e+06
# INGRESSOS                               1.0283e+06
# Name: 198, dtype: object
# NOM_COMPLERT    Ajuntament de Castellar de la Ribera
# CODI_ENS                                  1722400000
# DESPESES                                  1.1897e+06
# INGRESSOS                                     584850
# Name: 199, dtype: object
# NOM_COMPLERT    Ajuntament de Castellar de n'Hug
# CODI_ENS                              1722530008
# DESPESES                                  752988
# INGRESSOS                                 376494
# Name: 200, dtype: object
# NOM_COMPLERT    Ajuntament de Castellar del Vallès
# CODI_ENS                                1722660009
# DESPESES                               3.66359e+06
# INGRESSOS                              1.98568e+06
# Name: 201, dtype: object
# NOM_COMPLERT    Ajuntament de Castellbell i el Vilar
# CODI_ENS                                  1722720002
# DESPESES                                      977200
# INGRESSOS                                     488600
# Name: 202, dtype: object
# NOM_COMPLERT    Ajuntament de Castellbisbal
# CODI_ENS                         1722880001
# DESPESES                             628821
# INGRESSOS                            314411
# Name: 203, dtype: object
# NOM_COMPLERT    Ajuntament de Castellcir
# CODI_ENS                      1723050006
# DESPESES                     1.56598e+06
# INGRESSOS                         782989
# Name: 204, dtype: object
# NOM_COMPLERT    Ajuntament de Castelldans
# CODI_ENS                       1723270005
# DESPESES                           665860
# INGRESSOS                          335430
# Name: 205, dtype: object
# NOM_COMPLERT    Ajuntament de Castelldefels
# CODI_ENS                         1723330008
# DESPESES                        7.06451e+06
# INGRESSOS                       3.53225e+06
# Name: 206, dtype: object
# NOM_COMPLERT    Ajuntament de Castellet i la Gornal
# CODI_ENS                                 1723480001
# DESPESES                                     570756
# INGRESSOS                                    285378
# Name: 207, dtype: object
# NOM_COMPLERT    Ajuntament de Castellfollit de Riubregós
# CODI_ENS                                      1790110007
# DESPESES                                      2.1304e+06
# INGRESSOS                                     1.0652e+06
# Name: 208, dtype: object
# NOM_COMPLERT    Ajuntament de Castellfollit de la Roca
# CODI_ENS                                    1790260009
# DESPESES                                    4.8382e+06
# INGRESSOS                                   2.4191e+06
# Name: 209, dtype: object
# NOM_COMPLERT    Ajuntament de Castellfollit del Boix
# CODI_ENS                                  1790320002
# DESPESES                                 2.20149e+06
# INGRESSOS                                1.10075e+06
# Name: 210, dtype: object
# NOM_COMPLERT    Ajuntament de Castellgalí
# CODI_ENS                       2500240003
# DESPESES                      2.51877e+06
# INGRESSOS                     1.25939e+06
# Name: 211, dtype: object
# NOM_COMPLERT    Ajuntament de Castellnou de Bages
# CODI_ENS                               2500300000
# DESPESES                              9.82398e+06
# INGRESSOS                             4.91199e+06
# Name: 212, dtype: object
# NOM_COMPLERT    Ajuntament de Castellnou de Seana
# CODI_ENS                               2500450006
# DESPESES                              1.44803e+06
# INGRESSOS                                  724015
# Name: 213, dtype: object
# NOM_COMPLERT    Ajuntament de Castellolí
# CODI_ENS                      2500610007
# DESPESES                          804000
# INGRESSOS                         402000
# Name: 214, dtype: object
# NOM_COMPLERT    Ajuntament de Castellserà
# CODI_ENS                       2500770005
# DESPESES                       3.4088e+06
# INGRESSOS                      1.7044e+06
# Name: 215, dtype: object
# NOM_COMPLERT    Ajuntament de Castellterçol
# CODI_ENS                         2500830008
# DESPESES                        2.17849e+06
# INGRESSOS                       1.08924e+06
# Name: 216, dtype: object
# NOM_COMPLERT    Ajuntament de Castellvell del Camp
# CODI_ENS                                2500960009
# DESPESES                                1.7878e+06
# INGRESSOS                                   896900
# Name: 217, dtype: object
# NOM_COMPLERT    Ajuntament de Castellví de Rosanes
# CODI_ENS                                2501000000
# DESPESES                                    598496
# INGRESSOS                                   299748
# Name: 218, dtype: object
# NOM_COMPLERT    Ajuntament de Castellví de la Marca
# CODI_ENS                                 2501170005
# DESPESES                                1.59663e+07
# INGRESSOS                               7.98316e+06
# Name: 219, dtype: object
# NOM_COMPLERT    Ajuntament de Castelló d'Empúries
# CODI_ENS                               2501220002
# DESPESES                                4.116e+06
# INGRESSOS                               2.058e+06
# Name: 220, dtype: object
# NOM_COMPLERT    Ajuntament de Castelló de Farfanya
# CODI_ENS                                2501380001
# DESPESES                               4.17861e+06
# INGRESSOS                              2.08931e+06
# Name: 221, dtype: object
# NOM_COMPLERT    Ajuntament de Celrà
# CODI_ENS                 2501430008
# DESPESES                     681444
# INGRESSOS                    340822
# Name: 222, dtype: object
# NOM_COMPLERT    Ajuntament de Centelles
# CODI_ENS                     2501560009
# DESPESES                    1.24613e+06
# INGRESSOS                        623064
# Name: 223, dtype: object
# NOM_COMPLERT    Ajuntament de Cercs
# CODI_ENS                 2501690004
# DESPESES                4.60981e+06
# INGRESSOS               2.30491e+06
# Name: 224, dtype: object
# NOM_COMPLERT    Ajuntament de Cerdanyola del Vallès
# CODI_ENS                                 2501940003
# DESPESES                                9.42272e+06
# INGRESSOS                               4.71136e+06
# Name: 225, dtype: object
# NOM_COMPLERT    Ajuntament de Cervelló
# CODI_ENS                    2502080001
# DESPESES                   1.09085e+06
# INGRESSOS                       801523
# Name: 226, dtype: object
# NOM_COMPLERT    Ajuntament de Cervera
# CODI_ENS                   2502150006
# DESPESES                  5.13011e+06
# INGRESSOS                 2.56505e+06
# Name: 227, dtype: object
# NOM_COMPLERT    Ajuntament de Cervià de Ter
# CODI_ENS                         2502200000
# DESPESES                             536194
# INGRESSOS                            269097
# Name: 228, dtype: object
# NOM_COMPLERT    Ajuntament de Cervià de les Garrigues
# CODI_ENS                                   2502360009
# DESPESES                                    9.787e+06
# INGRESSOS                                  4.8485e+06
# Name: 229, dtype: object
# NOM_COMPLERT    Ajuntament de Cistella
# CODI_ENS                    2502540003
# DESPESES                      1.11e+07
# INGRESSOS                     5.55e+06
# Name: 230, dtype: object
# NOM_COMPLERT    Ajuntament de Ciutadilla
# CODI_ENS                      2502730008
# DESPESES                     2.47485e+06
# INGRESSOS                    1.23743e+06
# Name: 231, dtype: object
# NOM_COMPLERT    Ajuntament de Clariana de Cardener
# CODI_ENS                                2502920002
# DESPESES                               4.86787e+06
# INGRESSOS                              2.43393e+06
# Name: 232, dtype: object
# NOM_COMPLERT    Ajuntament de Colera
# CODI_ENS                  2503060009
# DESPESES                      735820
# INGRESSOS                     367910
# Name: 233, dtype: object
# NOM_COMPLERT    Ajuntament de Coll de Nargó
# CODI_ENS                         2503130008
# DESPESES                             208633
# INGRESSOS                            104842
# Name: 234, dtype: object
# NOM_COMPLERT    Ajuntament de Collbató
# CODI_ENS                    2503340003
# DESPESES                   2.50401e+06
# INGRESSOS                    1.252e+06
# Name: 235, dtype: object
# NOM_COMPLERT    Ajuntament de Colldejou
# CODI_ENS                     2503490004
# DESPESES                    7.86362e+06
# INGRESSOS                   3.93181e+06
# Name: 236, dtype: object
# NOM_COMPLERT    Ajuntament de Collsuspina
# CODI_ENS                       2503520002
# DESPESES                           909370
# INGRESSOS                          454685
# Name: 237, dtype: object
# NOM_COMPLERT    Ajuntament de Colomers
# CODI_ENS                    2503650006
# DESPESES                        453000
# INGRESSOS                       226500
# Name: 238, dtype: object
# NOM_COMPLERT    Ajuntament de Conca de Dalt
# CODI_ENS                         2503710007
# DESPESES                             961984
# INGRESSOS                            480992
# Name: 239, dtype: object
# NOM_COMPLERT    Ajuntament de Conesa
# CODI_ENS                  2503870005
# DESPESES                 3.85994e+06
# INGRESSOS                1.92997e+06
# Name: 240, dtype: object
# NOM_COMPLERT    Ajuntament de Constantí
# CODI_ENS                     2504040003
# DESPESES                    3.24126e+07
# INGRESSOS                   1.62063e+07
# Name: 241, dtype: object
# NOM_COMPLERT    Ajuntament de Copons
# CODI_ENS                  2504110007
# DESPESES                 1.46628e+06
# INGRESSOS                     733139
# Name: 242, dtype: object
# NOM_COMPLERT    Ajuntament de Corbera d'Ebre
# CODI_ENS                          2504260009
# DESPESES                         1.19382e+06
# INGRESSOS                             596910
# Name: 243, dtype: object
# NOM_COMPLERT    Ajuntament de Corbera de Llobregat
# CODI_ENS                                2504320002
# DESPESES                               4.10112e+06
# INGRESSOS                              2.05056e+06
# Name: 244, dtype: object
# NOM_COMPLERT    Ajuntament de Corbins
# CODI_ENS                   2504470005
# DESPESES                  1.47187e+06
# INGRESSOS                      780936
# Name: 245, dtype: object
# NOM_COMPLERT    Ajuntament de Cornellà de Llobregat
# CODI_ENS                                 2504500000
# DESPESES                                     151078
# INGRESSOS                                    262162
# Name: 246, dtype: object
# NOM_COMPLERT    Ajuntament de Cornellà del Terri
# CODI_ENS                              2504630008
# DESPESES                             1.15308e+06
# INGRESSOS                                 612775
# Name: 247, dtype: object
# NOM_COMPLERT    Ajuntament de Cornudella de Montsant
# CODI_ENS                                  2504850006
# DESPESES                                 3.07956e+06
# INGRESSOS                                1.61647e+06
# Name: 248, dtype: object
# NOM_COMPLERT    Ajuntament de Corçà
# CODI_ENS                 2504980001
# DESPESES                     321800
# INGRESSOS                    208150
# Name: 249, dtype: object
# NOM_COMPLERT    Ajuntament de Creixell
# CODI_ENS                    2505010007
# DESPESES                   7.60792e+06
# INGRESSOS                  3.80396e+06
# Name: 250, dtype: object
# NOM_COMPLERT    Ajuntament de Crespià
# CODI_ENS                   2505180001
# DESPESES                  5.53659e+06
# INGRESSOS                  2.7683e+06
# Name: 251, dtype: object
# NOM_COMPLERT    Ajuntament de Cruïlles, Monells i Sant Sadurní...
# CODI_ENS                                               2505230008
# DESPESES                                              3.59407e+06
# INGRESSOS                                             1.79704e+06
# Name: 252, dtype: object
# NOM_COMPLERT    Ajuntament de Cubelles
# CODI_ENS                    2505390004
# DESPESES                   2.59946e+06
# INGRESSOS                  1.30515e+06
# Name: 253, dtype: object
# NOM_COMPLERT    Ajuntament de Cubells
# CODI_ENS                   2505570005
# DESPESES                       788343
# ...
# CODI_ENS                   2516150006
# DESPESES                       895024
# INGRESSOS                      447512
# Name: 338, dtype: object
# NOM_COMPLERT    Ajuntament de Llorac
# CODI_ENS                  2516360009
# DESPESES                 1.13424e+06
# INGRESSOS                     567121
# Name: 339, dtype: object
# NOM_COMPLERT    Ajuntament de Llorenç del Penedès
# CODI_ENS                               2516410007
# DESPESES                              1.10074e+06
# INGRESSOS                                  550368
# Name: 340, dtype: object
# NOM_COMPLERT    Ajuntament de Lloret de Mar
# CODI_ENS                         2516540003
# DESPESES                             880627
# INGRESSOS                            440313
# Name: 341, dtype: object
# NOM_COMPLERT    Ajuntament de Lluçà
# CODI_ENS                 2516670005
# DESPESES                     282888
# INGRESSOS                    141469
# Name: 342, dtype: object
# NOM_COMPLERT    Ajuntament de Maials
# CODI_ENS                  2516730008
# DESPESES                      404094
# INGRESSOS                     202047
# Name: 343, dtype: object
# NOM_COMPLERT    Ajuntament de Maià de Montcal
# CODI_ENS                           2516890004
# DESPESES                               964550
# INGRESSOS                              482275
# Name: 344, dtype: object
# NOM_COMPLERT    Ajuntament de Maldà
# CODI_ENS                 2516920002
# DESPESES                     667808
# INGRESSOS                    333954
# Name: 345, dtype: object
# NOM_COMPLERT    Ajuntament de Malgrat de Mar
# CODI_ENS                          2517060009
# DESPESES                         1.12975e+06
# INGRESSOS                             570633
# Name: 346, dtype: object
# NOM_COMPLERT    Ajuntament de Malla
# CODI_ENS                 2517130008
# DESPESES                6.40258e+06
# INGRESSOS               3.20129e+06
# Name: 347, dtype: object
# NOM_COMPLERT    Ajuntament de Manlleu
# CODI_ENS                   2517280001
# DESPESES                  6.04475e+06
# INGRESSOS                 3.02237e+06
# Name: 348, dtype: object
# NOM_COMPLERT    Ajuntament de Manresa
# CODI_ENS                   2517340003
# DESPESES                  5.29819e+06
# INGRESSOS                 2.64909e+06
# Name: 349, dtype: object
# NOM_COMPLERT    Ajuntament de Margalef
# CODI_ENS                    2517490004
# DESPESES                   1.38948e+06
# INGRESSOS                       694741
# Name: 350, dtype: object
# NOM_COMPLERT    Ajuntament de Martorell
# CODI_ENS                     2517520002
# DESPESES                         794793
# INGRESSOS                        493423
# Name: 351, dtype: object
# NOM_COMPLERT    Ajuntament de Martorelles
# CODI_ENS                       2517650006
# DESPESES                      1.35003e+06
# INGRESSOS                          675016
# Name: 352, dtype: object
# NOM_COMPLERT    Ajuntament de Marçà
# CODI_ENS                 2517710007
# DESPESES                1.25238e+06
# INGRESSOS                    626191
# Name: 353, dtype: object
# NOM_COMPLERT    Ajuntament de Mas de Barberans
# CODI_ENS                            2517900000
# DESPESES                           1.12436e+06
# INGRESSOS                               640130
# Name: 354, dtype: object
# NOM_COMPLERT    Ajuntament de Masdenverge
# CODI_ENS                       2518040003
# DESPESES                           681292
# INGRESSOS                          340646
# Name: 355, dtype: object
# NOM_COMPLERT    Ajuntament de Masllorenç
# CODI_ENS                      2518110007
# DESPESES                     1.08268e+06
# INGRESSOS                         541339
# Name: 356, dtype: object
# NOM_COMPLERT    Ajuntament de Maspujols
# CODI_ENS                     2518260009
# DESPESES                    1.90437e+06
# INGRESSOS                        952184
# Name: 357, dtype: object
# NOM_COMPLERT    Ajuntament de Masquefa
# CODI_ENS                    2518320002
# DESPESES                   2.35026e+06
# INGRESSOS                  1.17413e+06
# Name: 358, dtype: object
# NOM_COMPLERT    Ajuntament de Massalcoreig
# CODI_ENS                        2518500000
# DESPESES                           1.4e+06
# INGRESSOS                           700000
# Name: 359, dtype: object
# NOM_COMPLERT    Ajuntament de Massoteres
# CODI_ENS                      2518630008
# DESPESES                          362036
# INGRESSOS                         181018
# Name: 360, dtype: object
# NOM_COMPLERT    Ajuntament de Matadepera
# CODI_ENS                      2518980001
# DESPESES                     4.64324e+06
# INGRESSOS                    2.32162e+06
# Name: 361, dtype: object
# NOM_COMPLERT    Ajuntament de Mataró
# CODI_ENS                  2519020002
# DESPESES                 1.24206e+06
# INGRESSOS                     621028
# Name: 362, dtype: object
# NOM_COMPLERT    Ajuntament de Maçanet de la Selva
# CODI_ENS                               2519190004
# DESPESES                               1.0817e+06
# INGRESSOS                                  540852
# Name: 363, dtype: object
# NOM_COMPLERT    Ajuntament de Mediona
# CODI_ENS                   2519240003
# DESPESES                  1.84158e+06
# INGRESSOS                      956397
# Name: 364, dtype: object
# NOM_COMPLERT    Ajuntament de Menàrguens
# CODI_ENS                      2519300000
# DESPESES                     1.99184e+06
# INGRESSOS                         995922
# Name: 365, dtype: object
# NOM_COMPLERT    Ajuntament de Mieres
# CODI_ENS                  2519450006
# DESPESES                 1.10313e+06
# INGRESSOS                     551563
# Name: 366, dtype: object
# NOM_COMPLERT    Ajuntament de Miralcamp
# CODI_ENS                     2519610007
# DESPESES                         517599
# INGRESSOS                        258899
# Name: 367, dtype: object
# NOM_COMPLERT    Ajuntament de Miravet
# CODI_ENS                   2519770005
# DESPESES                       441728
# INGRESSOS                      221184
# Name: 368, dtype: object
# NOM_COMPLERT    Ajuntament de Moià
# CODI_ENS                2520170005
# DESPESES                    610663
# INGRESSOS                   305331
# Name: 369, dtype: object
# NOM_COMPLERT    Ajuntament de Molins de Rei
# CODI_ENS                         2520220002
# DESPESES                             483854
# INGRESSOS                            242327
# Name: 370, dtype: object
# NOM_COMPLERT    Ajuntament de Mollerussa
# CODI_ENS                      2520380001
# DESPESES                     2.36391e+07
# INGRESSOS                    1.18196e+07
# Name: 371, dtype: object
# NOM_COMPLERT    Ajuntament de Mollet de Peralada
# CODI_ENS                              2520430008
# DESPESES                             3.79538e+06
# INGRESSOS                            2.19074e+06
# Name: 372, dtype: object
# NOM_COMPLERT    Ajuntament de Mollet del Vallès
# CODI_ENS                             2520560009
# DESPESES                            1.36284e+06
# INGRESSOS                                681420
# Name: 373, dtype: object
# NOM_COMPLERT    Ajuntament de Molló
# CODI_ENS                 2520690004
# DESPESES                     642240
# INGRESSOS                    321120
# Name: 374, dtype: object
# NOM_COMPLERT    Ajuntament de Monistrol de Calders
# CODI_ENS                                2520750006
# DESPESES                               1.71767e+07
# INGRESSOS                              8.58834e+06
# Name: 375, dtype: object
# NOM_COMPLERT    Ajuntament de Monistrol de Montserrat
# CODI_ENS                                   2520810007
# DESPESES                                  1.28527e+06
# INGRESSOS                                      645421
# Name: 376, dtype: object
# NOM_COMPLERT    Ajuntament de Mont-ral
# CODI_ENS                    2520940003
# DESPESES                   6.93252e+06
# INGRESSOS                  3.47385e+06
# Name: 377, dtype: object
# NOM_COMPLERT    Ajuntament de Mont-ras
# CODI_ENS                    2521080001
# DESPESES                     3.494e+06
# INGRESSOS                    1.747e+06
# Name: 378, dtype: object
# NOM_COMPLERT    Ajuntament de Mont-roig del Camp
# CODI_ENS                              2521150006
# DESPESES                             1.36038e+06
# INGRESSOS                                 680190
# Name: 379, dtype: object
# NOM_COMPLERT    Ajuntament de Montagut i Oix
# CODI_ENS                          2521200000
# DESPESES                              532800
# INGRESSOS                             266400
# Name: 380, dtype: object
# NOM_COMPLERT    Ajuntament de Montblanc
# CODI_ENS                     2521540003
# DESPESES                    1.17009e+06
# INGRESSOS                        590797
# Name: 381, dtype: object
# NOM_COMPLERT    Ajuntament de Montbrió del Camp
# CODI_ENS                             2521670005
# DESPESES                                 935284
# INGRESSOS                                467642
# Name: 382, dtype: object
# NOM_COMPLERT    Ajuntament de Montcada i Reixac
# CODI_ENS                             2521730008
# DESPESES                             3.0413e+07
# INGRESSOS                           1.52065e+07
# Name: 383, dtype: object
# NOM_COMPLERT    Ajuntament de Montclar
# CODI_ENS                    2521890004
# DESPESES                        604490
# INGRESSOS                       302245
# Name: 384, dtype: object
# NOM_COMPLERT    Ajuntament de Montellà i Martinet
# CODI_ENS                               2521920002
# DESPESES                                   502245
# INGRESSOS                                  255000
# Name: 385, dtype: object
# NOM_COMPLERT    Ajuntament de Montesquiu
# CODI_ENS                      2522060009
# DESPESES                     3.11739e+06
# INGRESSOS                    1.55869e+06
# Name: 386, dtype: object
# NOM_COMPLERT    Ajuntament de Montferrer i Castellbò
# CODI_ENS                                  2522130008
# DESPESES                                      743158
# INGRESSOS                                     371579
# Name: 387, dtype: object
# NOM_COMPLERT    Ajuntament de Montferri
# CODI_ENS                     2522280001
# DESPESES                         662882
# INGRESSOS                        331441
# Name: 388, dtype: object
# NOM_COMPLERT    Ajuntament de Montgai
# CODI_ENS                   2522340003
# DESPESES                  3.01184e+06
# INGRESSOS                 1.51855e+06
# Name: 389, dtype: object
# NOM_COMPLERT    Ajuntament de Montgat
# CODI_ENS                   2522490004
# DESPESES                       380300
# INGRESSOS                      190150
# Name: 390, dtype: object
# NOM_COMPLERT    Ajuntament de Montmajor
# CODI_ENS                     2522520002
# DESPESES                     1.7214e+06
# INGRESSOS                        860700
# Name: 391, dtype: object
# NOM_COMPLERT    Ajuntament de Montmeló
# CODI_ENS                    2522650006
# DESPESES                    1.0029e+06
# INGRESSOS                       501450
# Name: 392, dtype: object
# NOM_COMPLERT    Ajuntament de Montoliu de Lleida
# CODI_ENS                              2522710007
# DESPESES                             4.92998e+06
# INGRESSOS                            2.46499e+06
# Name: 393, dtype: object
# NOM_COMPLERT    Ajuntament de Montoliu de Segarra
# CODI_ENS                               2522870005
# DESPESES                               8.7767e+06
# INGRESSOS                             4.38835e+06
# Name: 394, dtype: object
# NOM_COMPLERT    Ajuntament de Montornès de Segarra
# CODI_ENS                                2523040003
# DESPESES                               3.08684e+06
# INGRESSOS                              1.54342e+06
# Name: 395, dtype: object
# NOM_COMPLERT    Ajuntament de Montornès del Vallès
# CODI_ENS                                2523110007
# DESPESES                               1.42953e+06
# INGRESSOS                                   714765
# Name: 396, dtype: object
# NOM_COMPLERT    Ajuntament de Montseny
# CODI_ENS                    2523260009
# DESPESES                   5.42206e+06
# INGRESSOS                  2.71103e+06
# Name: 397, dtype: object
# NOM_COMPLERT    Ajuntament de Muntanyola
# CODI_ENS                      2523470005
# DESPESES                     1.15695e+07
# INGRESSOS                    5.78473e+06
# Name: 398, dtype: object
# NOM_COMPLERT    Ajuntament de Mura
# CODI_ENS                2523850006
# DESPESES               1.66031e+06
# INGRESSOS                   830157
# Name: 399, dtype: object
# NOM_COMPLERT    Ajuntament de Móra d'Ebre
# CODI_ENS                       2523980001
# DESPESES                      1.36137e+06
# INGRESSOS                          680686
# Name: 400, dtype: object
# NOM_COMPLERT    Ajuntament de Móra la Nova
# CODI_ENS                        2524020002
# DESPESES                        2.8802e+06
# INGRESSOS                       1.4476e+06
# Name: 401, dtype: object
# NOM_COMPLERT    Ajuntament de Nalec
# CODI_ENS                 2524240003
# DESPESES                1.39786e+06
# INGRESSOS                    698930
# Name: 402, dtype: object
# NOM_COMPLERT    Ajuntament de Naut Aran
# CODI_ENS                     2524300000
# DESPESES                    9.95606e+06
# INGRESSOS                   4.97803e+06
# Name: 403, dtype: object
# NOM_COMPLERT    Ajuntament de Navarcles
# CODI_ENS                     2524450006
# DESPESES                    1.35544e+06
# INGRESSOS                        677721
# Name: 404, dtype: object
# NOM_COMPLERT    Ajuntament de Navata
# CODI_ENS                  2524580001
# DESPESES                 1.74961e+06
# INGRESSOS                     874806
# Name: 405, dtype: object
# NOM_COMPLERT    Ajuntament de Navàs
# CODI_ENS                 2524770005
# DESPESES                     344420
# INGRESSOS                    172210
# Name: 406, dtype: object
# NOM_COMPLERT    Ajuntament de Navès
# CODI_ENS                 2524830008
# DESPESES                 2.9452e+06
# INGRESSOS                1.4726e+06
# Name: 407, dtype: object
# NOM_COMPLERT    Ajuntament de Nulles
# CODI_ENS                  2524960009
# DESPESES                      466809
# INGRESSOS                     233404
# Name: 408, dtype: object
# NOM_COMPLERT    Ajuntament de Pacs del Penedès
# CODI_ENS                            2525090004
# DESPESES                                804506
# INGRESSOS                               388253
# Name: 409, dtype: object
# NOM_COMPLERT    Ajuntament de Palafolls
# CODI_ENS                     2525160009
# DESPESES                      2.394e+06
# INGRESSOS                     1.197e+06
# Name: 410, dtype: object
# NOM_COMPLERT    Ajuntament de Palafrugell
# CODI_ENS                       2525210007
# DESPESES                      1.50513e+06
# INGRESSOS                          783055
# Name: 411, dtype: object
# NOM_COMPLERT    Ajuntament de Palamós
# CODI_ENS                   2525370005
# DESPESES                       472773
# INGRESSOS                      236387
# Name: 412, dtype: object
# NOM_COMPLERT    Ajuntament de Palau de Santa Eulàlia
# CODI_ENS                                  2525420002
# DESPESES                                    2.01e+06
# INGRESSOS                                  1.005e+06
# Name: 413, dtype: object
# NOM_COMPLERT    Ajuntament de Palau-sator
# CODI_ENS                       2525550006
# DESPESES                      1.42355e+06
# INGRESSOS                          711775
# Name: 414, dtype: object
# NOM_COMPLERT    Ajuntament de Palau-saverdera
# CODI_ENS                           2590100000
# DESPESES                               973558
# INGRESSOS                              486779
# Name: 415, dtype: object
# NOM_COMPLERT    Ajuntament de Palau-solità i Plegamans
# CODI_ENS                                    2590250006
# DESPESES                                   1.22272e+06
# INGRESSOS                                       611358
# Name: 416, dtype: object
# NOM_COMPLERT    Ajuntament de Pallejà
# CODI_ENS                   2590310007
# DESPESES                       975200
# INGRESSOS                      487600
# Name: 417, dtype: object
# NOM_COMPLERT    Ajuntament de Palol de Revardit
# CODI_ENS                             2590460009
# DESPESES                            1.21454e+06
# INGRESSOS                                607871
# Name: 418, dtype: object
# NOM_COMPLERT    Ajuntament de Pals
# CODI_ENS                2590590004
# DESPESES               1.39822e+06
# INGRESSOS                   699111
# Name: 419, dtype: object
# NOM_COMPLERT    Ajuntament de Pardines
# CODI_ENS                    2590620002
# DESPESES                   1.28453e+06
# INGRESSOS                       736115
# Name: 420, dtype: object

# %% [markdown]
# ## Gestió de pressupostos de cada ajuntament

# %%
def get_presupostos(data):
    codi_ens = np.unique(data.CODI_ENS)
    nom = np.unique(data.NOM_COMPLERT)
    data_comparative = pd.DataFrame(columns=['NOM_COMPLERT','CODI_ENS', 'PRESSUPOST'])
    
    i = 0
    for ens in codi_ens:
      
        despesses = get_import_ajuntament(data, ens, 'D')
        ingressos = get_import_ajuntament(data, ens, 'I')
        data_comparative.loc[i] = [nom[i], ens,(ingressos-despesses)]

        i = i +1
        
    return data_comparative


presupostos = get_presupostos(data_sorted)

# %% [markdown]
# ## Ajuntaments amb beneficis i deutes
#
# ### Ajuntaments amb beneficis

# %%
benefici=presupostos.loc[presupostos.PRESSUPOST >= 0.0]
benefici.head(100)
# Out:
#                             NOM_COMPLERT    CODI_ENS  PRESSUPOST
# 246  Ajuntament de Cornellà de Llobregat  2504500000   111083.57

# %% [markdown]
# ### Número ajuntaments amb deutes

# %%
deute=presupostos.loc[presupostos.PRESSUPOST <= 0.0]
len(deute)
# Out:
# 881

# %% [markdown]
# ## Numero d'ajuntaments per descripcio en nivell 2

# %% [markdown]
# Aquesta investigació es realitza per poder observar després un cluster amb més claretat

# %%
def get_num_ajuntaments_by_desc(data, descripcio):
    r= np.unique(data.loc[(data.DESCRIPCIO == descripcio) & (data.NIVELL == '2') , ['NOM_COMPLERT']].NOM_COMPLERT)
    return len(r)

nivells= np.unique(data_sorted.NIVELL)

descriptions_bylevel2 = pd.DataFrame(columns=['DESCRIPCIO','NUM_AJUNTAMENTS'])

i=0
for nivell in nivells:
    if nivell=='2':
        descriptions = data_sorted.loc[data_sorted["NIVELL"] == nivell]
        lvl2_descriptions = np.unique(descriptions.DESCRIPCIO)
        for descripcio in lvl2_descriptions:
            num_ajuntaments= get_num_ajuntaments_by_desc(data_sorted, descripcio)
            descriptions_bylevel2.loc[i] = [descripcio,num_ajuntaments]
            i=i+1
descriptions_bylevel2=descriptions_bylevel2.sort_values(['NUM_AJUNTAMENTS'])
descriptions_bylevel2.tail(5)
# Out:
#                                  DESCRIPCIO NUM_AJUNTAMENTS
# 66      Impost sobre activitats econòmiques             880
# 103  Reparacions, manteniment i conservació             881
# 39                  De comunitats autònomes             881
# 106             Serveis de caràcter general             882
# 87    Material, subministraments i d'altres             882

# %% [markdown]
# ## Import de les dos descripcions que apareixen en més ajuntaments

# %%
from random import randint

def get_import_ajuntament_descripcio(data, codi_ens, descripcio):
    r= np.unique(data.loc[(data.CODI_ENS == codi_ens)  & (data.DESCRIPCIO == descripcio) , ['IMPORT']].IMPORT)
    suma=0
    for price in r:
            suma=suma+(float(price))
          
    return suma

def get_ingres_despesa_per_ajuntament(data):
    codi_ens = np.unique(data.CODI_ENS)
    nom = np.unique(data.NOM_COMPLERT)



    data_comparative = pd.DataFrame(columns=['NOM_COMPLERT','CODI_ENS', 'MATERIAL','SERVEIS'])
  
    i = 0

    for ens in codi_ens:
        material = get_import_ajuntament_descripcio(data, ens, "Material, subministraments i d'altres")
        serveis = get_import_ajuntament_descripcio(data, ens, 'Serveis de caràcter general')
      
        data_comparative.loc[i] = [nom[i], ens, material, serveis]
        i = i +1
   
        
        
    return data_comparative


material_serveis = get_ingres_despesa_per_ajuntament(data_sorted)
material_serveis.sort_values()

# %% [markdown]
# ### Número de descripcions per cada ajuntament

# %%
nom_ajuntaments= np.unique(data_sorted.NOM_COMPLERT)
data = pd.DataFrame(columns=['NOM_COMPLERT','DESCRIPCIO'])

i = 0
for nom in nom_ajuntaments:
    descriptions = data_sorted.loc[data_sorted["NOM_COMPLERT"] == nom]
    num_description = np.unique(descriptions.DESCRIPCIO)
    data.loc[i] = [nom, len(num_description)]
    
    i += 1

data.head(10)
# Out:
#                       NOM_COMPLERT DESCRIPCIO
# 0              Ajuntament d'Abrera        229
# 1            Ajuntament d'Agramunt        217
# 2  Ajuntament d'Aguilar de Segarra        236
# 3            Ajuntament d'Agullana        147
# 4          Ajuntament d'Aiguafreda        193
# 5         Ajuntament d'Aiguamúrcia        194
# 6           Ajuntament d'Aiguaviva        167
# 7              Ajuntament d'Aitona        248
# 8             Ajuntament d'Albanyà        114
# 9          Ajuntament d'Albatàrrec        103

# %% [markdown]
# # Clusters

# %% [markdown]
# ## Cluster de despeses i ingressos totals

# %%
dfIng_des_total=pd.DataFrame(columns=['INGRESSOS','DESPESES'])
dfIng_des_total['DESPESES']=ingres_despesa_total['DESPESES']
dfIng_des_total['INGRESSOS']=ingres_despesa_total['INGRESSOS']
features =['INGRESSOS','DESPESES']
# Separar les variables explicatives
x = dfIng_des_total.loc[:, features].values

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(x)
centros = kmeans.cluster_centers_
labels = kmeans.labels_
colors = ["g.","r.","c.","y.","b."]

for i in range(len(x)):
    plt.plot(x[i][0], x[i][1], colors[labels[i]], markersize = 10)


plt.scatter(centros[:, 0],centros[:, 1], marker = "x", s=50, linewidths = 5)

plt.show()

# %% [markdown]
# ### Cluster de ingressos i despes extret el valor aïllat

# %%
for i in range(len(x)):
    plt.plot(x[i][0], x[i][1], colors[labels[i]], markersize = 10)
plt.axis([0,250000000,0,500000000])  
plt.scatter(centros[:, 0],centros[:, 1], marker = "x", s=80, linewidths = 5)

plt.show()

# %% [markdown]
# ### Cluster Ingressos i Despesses aplicant PCA

# %%
xfeatures = StandardScaler().fit_transform(x)
# Keeping 2 components
pca = PCA(n_components=2)
# Explicative variables transformation
principalComponents = pca.fit_transform(xfeatures)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['INGRESSOS','DESPESES'])

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(principalDf)
fig, ax = plt.subplots(1,1)
ax.scatter(principalDf['INGRESSOS'],principalDf['DESPESES'], s=0.25, c=kmeans.labels_,linewidth=4)

# %%
features2 =['MATERIAL','SERVEIS']
# Separar les variables explicatives
x2 = material_serveis.loc[:, features2].values

# %%
kmeans = KMeans(n_clusters=8, random_state=0).fit(x2)
centros2 = kmeans.cluster_centers_
labels = kmeans.labels_
colors = ["g.","r.","c.","y.","b.","w.","m.","k."]

for i in range(len(x2)):
    plt.plot(x[i][0], x[i][1], colors[labels[i]], markersize = 10)

plt.scatter(centros2[:, 0],centros2[:, 1], marker = "x", s=100, linewidths = 5)

plt.show()
